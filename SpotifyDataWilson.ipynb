# %% [markdown]
# I am Amir Wilson and this is my Spotify Data Report. I love music and it is an easy and effective way to connect with people so I love that music was such a big part of this project. I believe there is a direct correlation between the "energy" track feature and the "popularity" track feature, making songs with more energy more popular. I believe this can be shown by using two of the first albums that came to my mind, and Spotify homepage :D, Graduation by Kanye West and Beauty Behind the Madness by The Weeknd.

# %%
import pandas as pd
import json
import requests
import base64
import urllib

# %% [markdown]
# App key allows me to see the Client ID and the Client Secret through the text file

# %%
app_key = pd.read_csv(r"Client_ID,Client_Secret.txt")

# %% [markdown]
# Defining app_id as the first value of Client_ID and app_token to the first value of Client_Secret

# %%
app_id = app_key['Client_ID'].iloc[0]
app_token = app_key['Client_Secret'].iloc[0]

# %% [markdown]
# Encoding the app_id and app_token to please Spotify

# %%
encoded_key = base64.b64encode(str(app_id + ":" + app_token).encode("ascii"))

# %% [markdown]
# Defining the url, data, and header

# %%
url = 'https://accounts.spotify.com/api/token'
data = {'grant_type':'client_credentials'}
header = {'Authorization': 'Basic {}'.format(encoded_key.decode("ascii"))}

# %% [markdown]
# Sending the above information to Spotify and checking to see if the status code is 200 which means everything is going okay

# %%
session_response = requests.post(url, data = data, headers = header)
session_response.status_code
# Out:
# 200

# %%
session_token = session_response.json()['access_token']
session_headers = {'Authorization': 'Bearer {}'.format(session_token)}
session_headers
# Out:
# {'Authorization': 'Bearer BQBBawPO58j_T67jzYUQbRtGL2oePbc7PGa0j5M4kmmBE1AgE2sEzEa2o9vOZvlFw2WJws5g9AxYE8dwlsTZVhvxjK9UA7ftWA2PKfu6rzsaWkIF0B4'}

# %%
 def get_session_token(SessionID, SessionKey):
     url = 'https://accounts.spotify.com/api/token'
     data = {'grant_type':'client_credentials'}
     encoded_key = base64.b64encode(str(SessionID + ":" + SessionKey).encode("ascii"))
     header = {'Authorization': 'Basic {}'.format(encoded_key.decode("ascii"))}
     response = requests.post(url, data = data, headers = header)
     
     print(response.status_code)
     
     return response.json()['access_token']

# %% [markdown]
# Keys are the client id and secret

# %%
keys = pd.read_csv(r"Client_ID,Client_Secret.txt")

# %% [markdown]
# Defining track features, tracks, and album tracks

# %%
t_features_ep = 'https://api.spotify.com/v1/audio-features'
tracks_ep = 'https://api.spotify.com/v1/tracks'
ab_tracks_ep = 'https://api.spotify.com/v1/albums/{}/tracks'

# %% [markdown]
# Creating an access token variable that uses the function get_session_token

# %%
access_token = get_session_token(keys['Client_ID'].iloc[0], keys['Client_Secret'].iloc[0])
# Out:
# 200

# %%
def api_call(endpoint_url, api_header):
    response = requests.get(endpoint_url, headers = api_header)
    print(response.status_code)
    return response.json()

# %% [markdown]
# Defining the header for this session

# %%
session_header = {'Authorization' : 'Bearer {}'.format(access_token)}

# %% [markdown]
# Album ids for Graduation and TBBTM

# %%
tw_album_id = '0P3oVJBFOv3TDXlYRhGL7s'
kw_album_id = '4SZko61aMnmgvNhfhgTuD3'

# %%
ab_tracks_ep.format(kw_album_id)
# Out:
# 'https://api.spotify.com/v1/albums/4SZko61aMnmgvNhfhgTuD3/tracks'

# %%
ab_tracks_ep.format(tw_album_id)
# Out:
# 'https://api.spotify.com/v1/albums/0P3oVJBFOv3TDXlYRhGL7s/tracks'

# %% [markdown]
# Using the function api call making sure that both albums are working within the notebook, looking for a response of 200 on both.

# %%
kw_album_response = api_call(ab_tracks_ep.format(kw_album_id), session_header)
tw_album_response = api_call(ab_tracks_ep.format(tw_album_id), session_header)
# Out:
# 200
# 200

# %% [markdown]
# Making a quick data frame for both albums and then displaying the data frame for Graduation just to make sure everything is working and that a dataframe is possible

# %%
kw_album_df = pd.DataFrame(kw_album_response['items'])
tw_album_df = pd.DataFrame(tw_album_response['items'])
kw_album_df.head()
# Out:
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#    duration_ms  explicit                                      external_urls  \
# 0       195093      True  {'spotify': 'https://open.spotify.com/track/6M...
# 1       167600      True  {'spotify': 'https://open.spotify.com/track/4U...
# 2       311866      True  {'spotify': 'https://open.spotify.com/track/0j...
# 3       243440      True  {'spotify': 'https://open.spotify.com/track/7r...
# 4       207000      True  {'spotify': 'https://open.spotify.com/track/4Z...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/6MXXY2eiWkpD...  6MXXY2eiWkpDCezVCc0cMH
# 1  https://api.spotify.com/v1/tracks/4UQMOPSUVJVi...  4UQMOPSUVJVicIQzjAcRRZ
# 2  https://api.spotify.com/v1/tracks/0j2T0R9dR9qd...  0j2T0R9dR9qdJYsB7ciXhf
# 3  https://api.spotify.com/v1/tracks/7rbECVPkY5UO...  7rbECVPkY5UODxoOUVKZnA
# 4  https://api.spotify.com/v1/tracks/4ZPdLEztrlZq...  4ZPdLEztrlZqbJkgHNw54L
#
#            name  track_number   type                                   uri  \
# 0  Good Morning             1  track  spotify:track:6MXXY2eiWkpDCezVCc0cMH
# 1      Champion             2  track  spotify:track:4UQMOPSUVJVicIQzjAcRRZ
# 2      Stronger             3  track  spotify:track:0j2T0R9dR9qdJYsB7ciXhf
# 3      I Wonder             4  track  spotify:track:7rbECVPkY5UODxoOUVKZnA
# 4     Good Life             5  track  spotify:track:4ZPdLEztrlZqbJkgHNw54L
#
#    is_local
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
kw_track_ids = ','.join(kw_album_df['id'].to_list())
tw_track_ids = ','.join(tw_album_df['id'].to_list())

# %% [markdown]
# Making sure track features and track info calls give 200 for both albums

# %%
kw_track_features = api_call(t_features_ep + '?ids={}'.format(kw_track_ids), session_header)
tw_track_features = api_call(t_features_ep + '?ids={}'.format(tw_track_ids), session_header)
# Out:
# 200
# 200

# %%
kw_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(kw_track_ids), session_header)
tw_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(tw_track_ids), session_header)
# Out:
# 200
# 200

# %% [markdown]
# Displaying the head of the data frame for the track features of Graduation

# %%
kw_features_df = pd.DataFrame(kw_track_features['audio_features'])
tw_features_df = pd.DataFrame(tw_track_features['audio_features'])
kw_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.480   0.631    7    -5.488     1       0.1160       0.07910
# 1         0.705   0.504    6    -8.307     1       0.2260       0.00299
# 2         0.617   0.716    1    -7.858     1       0.1360       0.00560
# 3         0.542   0.466    0    -8.668     1       0.0824       0.14100
# 4         0.439   0.808    1    -6.881     1       0.3460       0.00305
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000105     0.149    0.515   84.166  audio_features
# 1          0.000000     0.695    0.727  102.006  audio_features
# 2          0.000000     0.408    0.496  104.014  audio_features
# 3          0.000444     0.125    0.127  191.386  audio_features
# 4          0.000000     0.439    0.486   82.962  audio_features
#
#                        id                                   uri  \
# 0  6MXXY2eiWkpDCezVCc0cMH  spotify:track:6MXXY2eiWkpDCezVCc0cMH
# 1  4UQMOPSUVJVicIQzjAcRRZ  spotify:track:4UQMOPSUVJVicIQzjAcRRZ
# 2  0j2T0R9dR9qdJYsB7ciXhf  spotify:track:0j2T0R9dR9qdJYsB7ciXhf
# 3  7rbECVPkY5UODxoOUVKZnA  spotify:track:7rbECVPkY5UODxoOUVKZnA
# 4  4ZPdLEztrlZqbJkgHNw54L  spotify:track:4ZPdLEztrlZqbJkgHNw54L
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6MXXY2eiWkpD...
# 1  https://api.spotify.com/v1/tracks/4UQMOPSUVJVi...
# 2  https://api.spotify.com/v1/tracks/0j2T0R9dR9qd...
# 3  https://api.spotify.com/v1/tracks/7rbECVPkY5UO...
# 4  https://api.spotify.com/v1/tracks/4ZPdLEztrlZq...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6MXX...       195093
# 1  https://api.spotify.com/v1/audio-analysis/4UQM...       167600
# 2  https://api.spotify.com/v1/audio-analysis/0j2T...       311867
# 3  https://api.spotify.com/v1/audio-analysis/7rbE...       243440
# 4  https://api.spotify.com/v1/audio-analysis/4ZPd...       207000
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# Displaying the head of the data frame for the tracks of Graduation

# %%
kw_tracks_df = pd.DataFrame(kw_track_info['tracks'])
tw_tracks_df = pd.DataFrame(tw_track_info['tracks'])
kw_tracks_df.head()
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       195093      True  {'isrc': 'USUM70749081'}
# 1       167600      True  {'isrc': 'USUM70749083'}
# 2       311866      True  {'isrc': 'USUM70741299'}
# 3       243440      True  {'isrc': 'USUM70749085'}
# 4       207000      True  {'isrc': 'USUM70749087'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/6M...
# 1  {'spotify': 'https://open.spotify.com/track/4U...
# 2  {'spotify': 'https://open.spotify.com/track/0j...
# 3  {'spotify': 'https://open.spotify.com/track/7r...
# 4  {'spotify': 'https://open.spotify.com/track/4Z...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/6MXXY2eiWkpD...  6MXXY2eiWkpDCezVCc0cMH
# 1  https://api.spotify.com/v1/tracks/4UQMOPSUVJVi...  4UQMOPSUVJVicIQzjAcRRZ
# 2  https://api.spotify.com/v1/tracks/0j2T0R9dR9qd...  0j2T0R9dR9qdJYsB7ciXhf
# 3  https://api.spotify.com/v1/tracks/7rbECVPkY5UO...  7rbECVPkY5UODxoOUVKZnA
# 4  https://api.spotify.com/v1/tracks/4ZPdLEztrlZq...  4ZPdLEztrlZqbJkgHNw54L
#
#    is_local  is_playable          name  popularity  track_number   type  \
# 0     False         True  Good Morning          71             1  track
# 1     False         True      Champion          73             2  track
# 2     False         True      Stronger          79             3  track
# 3     False         True      I Wonder          81             4  track
# 4     False         True     Good Life          74             5  track
#
#                                     uri
# 0  spotify:track:6MXXY2eiWkpDCezVCc0cMH
# 1  spotify:track:4UQMOPSUVJVicIQzjAcRRZ
# 2  spotify:track:0j2T0R9dR9qdJYsB7ciXhf
# 3  spotify:track:7rbECVPkY5UODxoOUVKZnA
# 4  spotify:track:4ZPdLEztrlZqbJkgHNw54L

# %% [markdown]
# Merging the data frames for tracks and track features together because my hypothesis is about energy and popularity which are in different dataframes, it would be much easier to look at and analyze if together.

# %%
kw_merged = pd.merge(kw_features_df, kw_tracks_df, how = 'inner', on = 'id')
tw_merged = pd.merge(tw_features_df, tw_tracks_df, how = 'inner', on = 'id')
kw_merged.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.480   0.631    7    -5.488     1       0.1160       0.07910
# 1         0.705   0.504    6    -8.307     1       0.2260       0.00299
# 2         0.617   0.716    1    -7.858     1       0.1360       0.00560
# 3         0.542   0.466    0    -8.668     1       0.0824       0.14100
# 4         0.439   0.808    1    -6.881     1       0.3460       0.00305
#
#    instrumentalness  liveness  valence  ...              external_ids  \
# 0          0.000105     0.149    0.515  ...  {'isrc': 'USUM70749081'}
# 1          0.000000     0.695    0.727  ...  {'isrc': 'USUM70749083'}
# 2          0.000000     0.408    0.496  ...  {'isrc': 'USUM70741299'}
# 3          0.000444     0.125    0.127  ...  {'isrc': 'USUM70749085'}
# 4          0.000000     0.439    0.486  ...  {'isrc': 'USUM70749087'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/6M...
# 1  {'spotify': 'https://open.spotify.com/track/4U...
# 2  {'spotify': 'https://open.spotify.com/track/0j...
# 3  {'spotify': 'https://open.spotify.com/track/7r...
# 4  {'spotify': 'https://open.spotify.com/track/4Z...
#
#                                                 href is_local is_playable  \
# 0  https://api.spotify.com/v1/tracks/6MXXY2eiWkpD...    False        True
# 1  https://api.spotify.com/v1/tracks/4UQMOPSUVJVi...    False        True
# 2  https://api.spotify.com/v1/tracks/0j2T0R9dR9qd...    False        True
# 3  https://api.spotify.com/v1/tracks/7rbECVPkY5UO...    False        True
# 4  https://api.spotify.com/v1/tracks/4ZPdLEztrlZq...    False        True
#
#            name  popularity  track_number type_y  \
# 0  Good Morning          71             1  track
# 1      Champion          73             2  track
# 2      Stronger          79             3  track
# 3      I Wonder          81             4  track
# 4     Good Life          74             5  track
#
#                                   uri_y
# 0  spotify:track:6MXXY2eiWkpDCezVCc0cMH
# 1  spotify:track:4UQMOPSUVJVicIQzjAcRRZ
# 2  spotify:track:0j2T0R9dR9qdJYsB7ciXhf
# 3  spotify:track:7rbECVPkY5UODxoOUVKZnA
# 4  spotify:track:4ZPdLEztrlZqbJkgHNw54L
#
# [5 rows x 33 columns]

# %% [markdown]
# Identifying the artist name on the data frames

# %%
kw_merged['artist'] = 'Kanye West'
tw_merged['artist'] = 'The Weeknd'
kw_merged.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type_x', 'id', 'uri_x', 'track_href', 'analysis_url', 'duration_ms_x',
#        'time_signature', 'album', 'artists', 'disc_number', 'duration_ms_y',
#        'explicit', 'external_ids', 'external_urls', 'href', 'is_local',
#        'is_playable', 'name', 'popularity', 'track_number', 'type_y', 'uri_y',
#        'artist'],
#       dtype='object')

# %% [markdown]
# Displaying a data frame with both albums and all of the columns to get information on every song. Should make proving or disproving my hypothesis easier because every song from both albums are in the same dataframe.

# %%
artist_compare = pd.concat([kw_merged, tw_merged], axis = 0)
artist_compare
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.480   0.631    7    -5.488     1       0.1160       0.07910
# 1          0.705   0.504    6    -8.307     1       0.2260       0.00299
# 2          0.617   0.716    1    -7.858     1       0.1360       0.00560
# 3          0.542   0.466    0    -8.668     1       0.0824       0.14100
# 4          0.439   0.808    1    -6.881     1       0.3460       0.00305
# 5          0.587   0.620    5    -6.133     0       0.0420       0.01220
# 6          0.480   0.624    1    -6.131     1       0.3820       0.04420
# 7          0.661   0.442   10    -7.298     0       0.0284       0.06960
# 8          0.639   0.628    6    -7.578     0       0.0398       0.03810
# 9          0.631   0.623    8    -6.971     1       0.2640       0.46600
# 10         0.423   0.643    6    -7.261     1       0.2870       0.04550
# 11         0.670   0.747    1    -7.059     1       0.1890       0.33700
# 12         0.506   0.742   11    -6.248     0       0.2640       0.21300
# 13         0.696   0.526   11   -10.504     0       0.2290       0.17800
# 0          0.581   0.652   11    -5.039     0       0.0496       0.43900
# 1          0.666   0.485    0    -9.850     0       0.0530       0.03550
# 2          0.583   0.454    1   -11.091     0       0.0425       0.26500
# 3          0.572   0.631    7    -9.836     0       0.0476       0.22200
# 4          0.585   0.564    0    -7.063     0       0.0515       0.06710
# 5          0.372   0.478    7    -9.835     0       0.0503       0.48200
# 6          0.705   0.769    9    -5.526     0       0.0425       0.11300
# 7          0.603   0.563    6    -8.313     1       0.0270       0.14700
# 8          0.657   0.291    2    -8.275     0       0.0348       0.40500
# 9          0.505   0.680    7    -4.993     1       0.0714       0.07960
# 10         0.377   0.329    0    -9.670     0       0.0569       0.13100
# 11         0.501   0.403    7    -9.611     1       0.0747       0.11600
# 12         0.551   0.405    0   -12.756     0       0.0398       0.44300
# 13         0.626   0.583   10    -7.574     0       0.0435       0.10500
#
#     instrumentalness  liveness  valence  ...  \
# 0           0.000105    0.1490   0.5150  ...
# 1           0.000000    0.6950   0.7270  ...
# 2           0.000000    0.4080   0.4960  ...
# 3           0.000444    0.1250   0.1270  ...
# 4           0.000000    0.4390   0.4860  ...
# 5           0.000000    0.8200   0.1060  ...
# 6           0.000000    0.3370   0.7130  ...
# 7           0.000012    0.1360   0.3060  ...
# 8           0.000000    0.3860   0.4300  ...
# 9           0.000002    0.1510   0.7650  ...
# 10          0.000000    0.1720   0.7080  ...
# 11          0.000000    0.1150   0.9180  ...
# 12          0.000000    0.0642   0.3010  ...
# 13          0.000000    0.1920   0.6910  ...
# 0           0.000000    0.3510   0.3580  ...
# 1           0.000599    0.5040   0.2870  ...
# 2           0.000000    0.1810   0.3090  ...
# 3           0.000000    0.1350   0.0713  ...
# 4           0.000000    0.1350   0.1370  ...
# 5           0.000000    0.0844   0.2540  ...
# 6           0.000000    0.1050   0.5830  ...
# 7           0.000000    0.1090   0.2340  ...
# 8           0.000000    0.0771   0.4050  ...
# 9           0.000000    0.0465   0.5390  ...
# 10          0.006540    0.2790   0.0528  ...
# 11          0.000010    0.1240   0.2700  ...
# 12          0.000217    0.1100   0.3410  ...
# 13          0.000000    0.1150   0.3350  ...
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/6M...
# 1   {'spotify': 'https://open.spotify.com/track/4U...
# 2   {'spotify': 'https://open.spotify.com/track/0j...
# 3   {'spotify': 'https://open.spotify.com/track/7r...
# 4   {'spotify': 'https://open.spotify.com/track/4Z...
# 5   {'spotify': 'https://open.spotify.com/track/0m...
# 6   {'spotify': 'https://open.spotify.com/track/73...
# 7   {'spotify': 'https://open.spotify.com/track/7D...
# 8   {'spotify': 'https://open.spotify.com/track/5T...
# 9   {'spotify': 'https://open.spotify.com/track/0N...
# 10  {'spotify': 'https://open.spotify.com/track/0l...
# 11  {'spotify': 'https://open.spotify.com/track/4i...
# 12  {'spotify': 'https://open.spotify.com/track/2L...
# 13  {'spotify': 'https://open.spotify.com/track/3b...
# 0   {'spotify': 'https://open.spotify.com/track/03...
# 1   {'spotify': 'https://open.spotify.com/track/1b...
# 2   {'spotify': 'https://open.spotify.com/track/1m...
# 3   {'spotify': 'https://open.spotify.com/track/4P...
# 4   {'spotify': 'https://open.spotify.com/track/7f...
# 5   {'spotify': 'https://open.spotify.com/track/7u...
# 6   {'spotify': 'https://open.spotify.com/track/22...
# 7   {'spotify': 'https://open.spotify.com/track/6C...
# 8   {'spotify': 'https://open.spotify.com/track/4f...
# 9   {'spotify': 'https://open.spotify.com/track/25...
# 10  {'spotify': 'https://open.spotify.com/track/3H...
# 11  {'spotify': 'https://open.spotify.com/track/6J...
# 12  {'spotify': 'https://open.spotify.com/track/1g...
# 13  {'spotify': 'https://open.spotify.com/track/0w...
#
#                                                  href is_local is_playable  \
# 0   https://api.spotify.com/v1/tracks/6MXXY2eiWkpD...    False        True
# 1   https://api.spotify.com/v1/tracks/4UQMOPSUVJVi...    False        True
# 2   https://api.spotify.com/v1/tracks/0j2T0R9dR9qd...    False        True
# 3   https://api.spotify.com/v1/tracks/7rbECVPkY5UO...    False        True
# 4   https://api.spotify.com/v1/tracks/4ZPdLEztrlZq...    False        True
# 5   https://api.spotify.com/v1/tracks/0mEdbdeRFQwB...    False        True
# 6   https://api.spotify.com/v1/tracks/7387VaiHpOsS...    False        True
# 7   https://api.spotify.com/v1/tracks/7DRuzSlhjKad...    False        True
# 8   https://api.spotify.com/v1/tracks/5TRPicyLGbAF...    False        True
# 9   https://api.spotify.com/v1/tracks/0NrtwAmRAdLx...    False        True
# 10  https://api.spotify.com/v1/tracks/0lWjRSzq5chA...    False        True
# 11  https://api.spotify.com/v1/tracks/4iz9lGMjU1lX...    False        True
# 12  https://api.spotify.com/v1/tracks/2L47m9erkB5K...    False        True
# 13  https://api.spotify.com/v1/tracks/3bhyo2ED5Yd4...    False        True
# 0   https://api.spotify.com/v1/tracks/03j354P848Kt...    False        True
# 1   https://api.spotify.com/v1/tracks/1bAvtmTl0F9l...    False        True
# 2   https://api.spotify.com/v1/tracks/1mhVXWduD8Re...    False        True
# 3   https://api.spotify.com/v1/tracks/4PhsKqMdgMEU...    False        True
# 4   https://api.spotify.com/v1/tracks/7fBv7CLKzipR...    False        True
# 5   https://api.spotify.com/v1/tracks/7uJH0YdSZL6p...    False        True
# 6   https://api.spotify.com/v1/tracks/22VdIZQfgXJe...    False        True
# 7   https://api.spotify.com/v1/tracks/6C6fHTuFUxVt...    False        True
# 8   https://api.spotify.com/v1/tracks/4frLb7nWtsz2...    False        True
# 9   https://api.spotify.com/v1/tracks/25KybV9BOUlv...    False        True
# 10  https://api.spotify.com/v1/tracks/3H3qBumaYj67...    False        True
# 11  https://api.spotify.com/v1/tracks/6J7PIkhtHwmF...    False        True
# 12  https://api.spotify.com/v1/tracks/1gZADNt16Oh2...    False        True
# 13  https://api.spotify.com/v1/tracks/0wzPHTgOtFID...    False        True
#
#                                 name popularity  track_number  type_y  \
# 0                       Good Morning         71             1   track
# 1                           Champion         73             2   track
# 2                           Stronger         79             3   track
# 3                           I Wonder         81             4   track
# 4                          Good Life         74             5   track
# 5              Can't Tell Me Nothing         79             6   track
# 6                        Barry Bonds         61             7   track
# 7                Drunk and Hot Girls         59             8   track
# 8                    Flashing Lights         83             9   track
# 9                    Everything I Am         73            10   track
# 10                         The Glory         63            11   track
# 11                        Homecoming         80            12   track
# 12                       Big Brother         61            13   track
# 13                        Good Night         60            14   track
# 0                          Real Life         57             1   track
# 1                             Losers         57             2   track
# 2                  Tell Your Friends         64             3   track
# 3                              Often         79             4   track
# 4                          The Hills         84             5   track
# 5                         Acquainted         71             6   track
# 6                 Can't Feel My Face         80             7   track
# 7                          Shameless         62             8   track
# 8   Earned It (Fifty Shades Of Grey)         71             9   track
# 9                       In The Night         71            10   track
# 10                        As You Are         63            11   track
# 11                        Dark Times         59            12   track
# 12                          Prisoner         64            13   track
# 13                             Angel         59            14   track
#
#                                    uri_y      artist
# 0   spotify:track:6MXXY2eiWkpDCezVCc0cMH  Kanye West
# 1   spotify:track:4UQMOPSUVJVicIQzjAcRRZ  Kanye West
# 2   spotify:track:0j2T0R9dR9qdJYsB7ciXhf  Kanye West
# 3   spotify:track:7rbECVPkY5UODxoOUVKZnA  Kanye West
# 4   spotify:track:4ZPdLEztrlZqbJkgHNw54L  Kanye West
# 5   spotify:track:0mEdbdeRFQwBhN4xfyIeUM  Kanye West
# 6   spotify:track:7387VaiHpOsSIZ5nmjseya  Kanye West
# 7   spotify:track:7DRuzSlhjKadgdsQRYZ0tr  Kanye West
# 8   spotify:track:5TRPicyLGbAF2LGBFbHGvO  Kanye West
# 9   spotify:track:0NrtwAmRAdLxua31SzHvXr  Kanye West
# 10  spotify:track:0lWjRSzq5chA9fps3pM8Zr  Kanye West
# 11  spotify:track:4iz9lGMjU1lXS51oPmUmTe  Kanye West
# 12  spotify:track:2L47m9erkB5KBZcaqWtYen  Kanye West
# 13  spotify:track:3bhyo2ED5Yd4RLydQBDtD6  Kanye West
# 0   spotify:track:03j354P848KtNU2FVSwkDG  The Weeknd
# 1   spotify:track:1bAvtmTl0F9loyz9AwPwp7  The Weeknd
# 2   spotify:track:1mhVXWduD8ReDwusfaHNwU  The Weeknd
# 3   spotify:track:4PhsKqMdgMEUSstTDAmMpg  The Weeknd
# 4   spotify:track:7fBv7CLKzipRk6EC6TWHOB  The Weeknd
# 5   spotify:track:7uJH0YdSZL6psjxI6Xy08b  The Weeknd
# 6   spotify:track:22VdIZQfgXJea34mQxlt81  The Weeknd
# 7   spotify:track:6C6fHTuFUxVtJpBOOaMvJr  The Weeknd
# 8   spotify:track:4frLb7nWtsz2ymBE6k2GRP  The Weeknd
# 9   spotify:track:25KybV9BOUlvcnv7nN3Pyo  The Weeknd
# 10  spotify:track:3H3qBumaYj67PT3aMEBvAP  The Weeknd
# 11  spotify:track:6J7PIkhtHwmFjPLq0SyuPj  The Weeknd
# 12  spotify:track:1gZADNt16Oh23jWyMYRk4p  The Weeknd
# 13  spotify:track:0wzPHTgOtFIDhk2rD3Au4x  The Weeknd
#
# [28 rows x 34 columns]

# %% [markdown]
# Sorting the data frame by the most popular.

# %%
pop_df = artist_compare.sort_values('popular')
pop_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1          0.666   0.485    0    -9.850     0       0.0530       0.03550
# 0          0.581   0.652   11    -5.039     0       0.0496       0.43900
# 13         0.626   0.583   10    -7.574     0       0.0435       0.10500
# 11         0.501   0.403    7    -9.611     1       0.0747       0.11600
# 7          0.661   0.442   10    -7.298     0       0.0284       0.06960
# 13         0.696   0.526   11   -10.504     0       0.2290       0.17800
# 6          0.480   0.624    1    -6.131     1       0.3820       0.04420
# 12         0.506   0.742   11    -6.248     0       0.2640       0.21300
# 7          0.603   0.563    6    -8.313     1       0.0270       0.14700
# 10         0.377   0.329    0    -9.670     0       0.0569       0.13100
# 10         0.423   0.643    6    -7.261     1       0.2870       0.04550
# 12         0.551   0.405    0   -12.756     0       0.0398       0.44300
# 2          0.583   0.454    1   -11.091     0       0.0425       0.26500
# 5          0.372   0.478    7    -9.835     0       0.0503       0.48200
# 8          0.657   0.291    2    -8.275     0       0.0348       0.40500
# 9          0.505   0.680    7    -4.993     1       0.0714       0.07960
# 0          0.480   0.631    7    -5.488     1       0.1160       0.07910
# 9          0.631   0.623    8    -6.971     1       0.2640       0.46600
# 1          0.705   0.504    6    -8.307     1       0.2260       0.00299
# 4          0.439   0.808    1    -6.881     1       0.3460       0.00305
# 2          0.617   0.716    1    -7.858     1       0.1360       0.00560
# 5          0.587   0.620    5    -6.133     0       0.0420       0.01220
# 3          0.572   0.631    7    -9.836     0       0.0476       0.22200
# 6          0.705   0.769    9    -5.526     0       0.0425       0.11300
# 11         0.670   0.747    1    -7.059     1       0.1890       0.33700
# 3          0.542   0.466    0    -8.668     1       0.0824       0.14100
# 8          0.639   0.628    6    -7.578     0       0.0398       0.03810
# 4          0.585   0.564    0    -7.063     0       0.0515       0.06710
#
#     instrumentalness  liveness  valence  ...  \
# 1           0.000599    0.5040   0.2870  ...
# 0           0.000000    0.3510   0.3580  ...
# 13          0.000000    0.1150   0.3350  ...
# 11          0.000010    0.1240   0.2700  ...
# 7           0.000012    0.1360   0.3060  ...
# 13          0.000000    0.1920   0.6910  ...
# 6           0.000000    0.3370   0.7130  ...
# 12          0.000000    0.0642   0.3010  ...
# 7           0.000000    0.1090   0.2340  ...
# 10          0.006540    0.2790   0.0528  ...
# 10          0.000000    0.1720   0.7080  ...
# 12          0.000217    0.1100   0.3410  ...
# 2           0.000000    0.1810   0.3090  ...
# 5           0.000000    0.0844   0.2540  ...
# 8           0.000000    0.0771   0.4050  ...
# 9           0.000000    0.0465   0.5390  ...
# 0           0.000105    0.1490   0.5150  ...
# 9           0.000002    0.1510   0.7650  ...
# 1           0.000000    0.6950   0.7270  ...
# 4           0.000000    0.4390   0.4860  ...
# 2           0.000000    0.4080   0.4960  ...
# 5           0.000000    0.8200   0.1060  ...
# 3           0.000000    0.1350   0.0713  ...
# 6           0.000000    0.1050   0.5830  ...
# 11          0.000000    0.1150   0.9180  ...
# 3           0.000444    0.1250   0.1270  ...
# 8           0.000000    0.3860   0.4300  ...
# 4           0.000000    0.1350   0.1370  ...
#
#                                         external_urls  \
# 1   {'spotify': 'https://open.spotify.com/track/1b...
# 0   {'spotify': 'https://open.spotify.com/track/03...
# 13  {'spotify': 'https://open.spotify.com/track/0w...
# 11  {'spotify': 'https://open.spotify.com/track/6J...
# 7   {'spotify': 'https://open.spotify.com/track/7D...
# 13  {'spotify': 'https://open.spotify.com/track/3b...
# 6   {'spotify': 'https://open.spotify.com/track/73...
# 12  {'spotify': 'https://open.spotify.com/track/2L...
# 7   {'spotify': 'https://open.spotify.com/track/6C...
# 10  {'spotify': 'https://open.spotify.com/track/3H...
# 10  {'spotify': 'https://open.spotify.com/track/0l...
# 12  {'spotify': 'https://open.spotify.com/track/1g...
# 2   {'spotify': 'https://open.spotify.com/track/1m...
# 5   {'spotify': 'https://open.spotify.com/track/7u...
# 8   {'spotify': 'https://open.spotify.com/track/4f...
# 9   {'spotify': 'https://open.spotify.com/track/25...
# 0   {'spotify': 'https://open.spotify.com/track/6M...
# 9   {'spotify': 'https://open.spotify.com/track/0N...
# 1   {'spotify': 'https://open.spotify.com/track/4U...
# 4   {'spotify': 'https://open.spotify.com/track/4Z...
# 2   {'spotify': 'https://open.spotify.com/track/0j...
# 5   {'spotify': 'https://open.spotify.com/track/0m...
# 3   {'spotify': 'https://open.spotify.com/track/4P...
# 6   {'spotify': 'https://open.spotify.com/track/22...
# 11  {'spotify': 'https://open.spotify.com/track/4i...
# 3   {'spotify': 'https://open.spotify.com/track/7r...
# 8   {'spotify': 'https://open.spotify.com/track/5T...
# 4   {'spotify': 'https://open.spotify.com/track/7f...
#
#                                                  href is_local is_playable  \
# 1   https://api.spotify.com/v1/tracks/1bAvtmTl0F9l...    False        True
# 0   https://api.spotify.com/v1/tracks/03j354P848Kt...    False        True
# 13  https://api.spotify.com/v1/tracks/0wzPHTgOtFID...    False        True
# 11  https://api.spotify.com/v1/tracks/6J7PIkhtHwmF...    False        True
# 7   https://api.spotify.com/v1/tracks/7DRuzSlhjKad...    False        True
# 13  https://api.spotify.com/v1/tracks/3bhyo2ED5Yd4...    False        True
# 6   https://api.spotify.com/v1/tracks/7387VaiHpOsS...    False        True
# 12  https://api.spotify.com/v1/tracks/2L47m9erkB5K...    False        True
# 7   https://api.spotify.com/v1/tracks/6C6fHTuFUxVt...    False        True
# 10  https://api.spotify.com/v1/tracks/3H3qBumaYj67...    False        True
# 10  https://api.spotify.com/v1/tracks/0lWjRSzq5chA...    False        True
# 12  https://api.spotify.com/v1/tracks/1gZADNt16Oh2...    False        True
# 2   https://api.spotify.com/v1/tracks/1mhVXWduD8Re...    False        True
# 5   https://api.spotify.com/v1/tracks/7uJH0YdSZL6p...    False        True
# 8   https://api.spotify.com/v1/tracks/4frLb7nWtsz2...    False        True
# 9   https://api.spotify.com/v1/tracks/25KybV9BOUlv...    False        True
# 0   https://api.spotify.com/v1/tracks/6MXXY2eiWkpD...    False        True
# 9   https://api.spotify.com/v1/tracks/0NrtwAmRAdLx...    False        True
# 1   https://api.spotify.com/v1/tracks/4UQMOPSUVJVi...    False        True
# 4   https://api.spotify.com/v1/tracks/4ZPdLEztrlZq...    False        True
# 2   https://api.spotify.com/v1/tracks/0j2T0R9dR9qd...    False        True
# 5   https://api.spotify.com/v1/tracks/0mEdbdeRFQwB...    False        True
# 3   https://api.spotify.com/v1/tracks/4PhsKqMdgMEU...    False        True
# 6   https://api.spotify.com/v1/tracks/22VdIZQfgXJe...    False        True
# 11  https://api.spotify.com/v1/tracks/4iz9lGMjU1lX...    False        True
# 3   https://api.spotify.com/v1/tracks/7rbECVPkY5UO...    False        True
# 8   https://api.spotify.com/v1/tracks/5TRPicyLGbAF...    False        True
# 4   https://api.spotify.com/v1/tracks/7fBv7CLKzipR...    False        True
#
#                                 name popularity  track_number  type_y  \
# 1                             Losers         57             2   track
# 0                          Real Life         57             1   track
# 13                             Angel         59            14   track
# 11                        Dark Times         59            12   track
# 7                Drunk and Hot Girls         59             8   track
# 13                        Good Night         60            14   track
# 6                        Barry Bonds         61             7   track
# 12                       Big Brother         61            13   track
# 7                          Shameless         62             8   track
# 10                        As You Are         63            11   track
# 10                         The Glory         63            11   track
# 12                          Prisoner         64            13   track
# 2                  Tell Your Friends         64             3   track
# 5                         Acquainted         71             6   track
# 8   Earned It (Fifty Shades Of Grey)         71             9   track
# 9                       In The Night         71            10   track
# 0                       Good Morning         71             1   track
# 9                    Everything I Am         73            10   track
# 1                           Champion         73             2   track
# 4                          Good Life         74             5   track
# 2                           Stronger         79             3   track
# 5              Can't Tell Me Nothing         79             6   track
# 3                              Often         79             4   track
# 6                 Can't Feel My Face         80             7   track
# 11                        Homecoming         80            12   track
# 3                           I Wonder         81             4   track
# 8                    Flashing Lights         83             9   track
# 4                          The Hills         84             5   track
#
#                                    uri_y      artist
# 1   spotify:track:1bAvtmTl0F9loyz9AwPwp7  The Weeknd
# 0   spotify:track:03j354P848KtNU2FVSwkDG  The Weeknd
# 13  spotify:track:0wzPHTgOtFIDhk2rD3Au4x  The Weeknd
# 11  spotify:track:6J7PIkhtHwmFjPLq0SyuPj  The Weeknd
# 7   spotify:track:7DRuzSlhjKadgdsQRYZ0tr  Kanye West
# 13  spotify:track:3bhyo2ED5Yd4RLydQBDtD6  Kanye West
# 6   spotify:track:7387VaiHpOsSIZ5nmjseya  Kanye West
# 12  spotify:track:2L47m9erkB5KBZcaqWtYen  Kanye West
# 7   spotify:track:6C6fHTuFUxVtJpBOOaMvJr  The Weeknd
# 10  spotify:track:3H3qBumaYj67PT3aMEBvAP  The Weeknd
# 10  spotify:track:0lWjRSzq5chA9fps3pM8Zr  Kanye West
# 12  spotify:track:1gZADNt16Oh23jWyMYRk4p  The Weeknd
# 2   spotify:track:1mhVXWduD8ReDwusfaHNwU  The Weeknd
# 5   spotify:track:7uJH0YdSZL6psjxI6Xy08b  The Weeknd
# 8   spotify:track:4frLb7nWtsz2ymBE6k2GRP  The Weeknd
# 9   spotify:track:25KybV9BOUlvcnv7nN3Pyo  The Weeknd
# 0   spotify:track:6MXXY2eiWkpDCezVCc0cMH  Kanye West
# 9   spotify:track:0NrtwAmRAdLxua31SzHvXr  Kanye West
# 1   spotify:track:4UQMOPSUVJVicIQzjAcRRZ  Kanye West
# 4   spotify:track:4ZPdLEztrlZqbJkgHNw54L  Kanye West
# 2   spotify:track:0j2T0R9dR9qdJYsB7ciXhf  Kanye West
# 5   spotify:track:0mEdbdeRFQwBhN4xfyIeUM  Kanye West
# 3   spotify:track:4PhsKqMdgMEUSstTDAmMpg  The Weeknd
# 6   spotify:track:22VdIZQfgXJea34mQxlt81  The Weeknd
# 11  spotify:track:4iz9lGMjU1lXS51oPmUmTe  Kanye West
# 3   spotify:track:7rbECVPkY5UODxoOUVKZnA  Kanye West
# 8   spotify:track:5TRPicyLGbAF2LGBFbHGvO  Kanye West
# 4   spotify:track:7fBv7CLKzipRk6EC6TWHOB  The Weeknd
#
# [28 rows x 34 columns]

# %% [markdown]
# I decided to only display the columns of the information I actually needed to assess my hypothesis that being the artist and track name as well as the energy and popularity rating.

# %%
pop_df[['artist', 'name', 'energy', 'popularity']]
# Out:
#         artist                              name  energy  popularity
# 1   The Weeknd                            Losers   0.485          57
# 0   The Weeknd                         Real Life   0.652          57
# 13  The Weeknd                             Angel   0.583          59
# 11  The Weeknd                        Dark Times   0.403          59
# 7   Kanye West               Drunk and Hot Girls   0.442          59
# 13  Kanye West                        Good Night   0.526          60
# 6   Kanye West                       Barry Bonds   0.624          61
# 12  Kanye West                       Big Brother   0.742          61
# 7   The Weeknd                         Shameless   0.563          62
# 10  The Weeknd                        As You Are   0.329          63
# 10  Kanye West                         The Glory   0.643          63
# 12  The Weeknd                          Prisoner   0.405          64
# 2   The Weeknd                 Tell Your Friends   0.454          64
# 5   The Weeknd                        Acquainted   0.478          71
# 8   The Weeknd  Earned It (Fifty Shades Of Grey)   0.291          71
# 9   The Weeknd                      In The Night   0.680          71
# 0   Kanye West                      Good Morning   0.631          71
# 9   Kanye West                   Everything I Am   0.623          73
# 1   Kanye West                          Champion   0.504          73
# 4   Kanye West                         Good Life   0.808          74
# 2   Kanye West                          Stronger   0.716          79
# 5   Kanye West             Can't Tell Me Nothing   0.620          79
# 3   The Weeknd                             Often   0.631          79
# 6   The Weeknd                Can't Feel My Face   0.769          80
# 11  Kanye West                        Homecoming   0.747          80
# 3   Kanye West                          I Wonder   0.466          81
# 8   Kanye West                   Flashing Lights   0.628          83
# 4   The Weeknd                         The Hills   0.564          84

# %% [markdown]
# My conclusion is that there was no real evidence of a correlation between energy and popularity at least in the data set I decided to use. I really enjoyed this project as it allowed me to really see how far I've come in even being comfortable with data. I wanted to do a line graph or scatter plot in the notebook but we still don't know how so I did my own on a separate platform. It made me certain that my theory was wrong and was significantly easier to consume and process. I had no real desire for my theory to be proven or disproven I more so just wanted to work it out and go through the process of figuring it out. I will likely add a submission comment with the picture of the graph I made. I believe a more diverse data set like a playlist might have made this project more fun and may have even proven my hypothesis, that would be a great pivot for the future.
